# %%
import pandas as pd
from evaluate import *
from overlap_evaluate import *

import json

# %%
results = pd.read_csv("results/nq/t5-xl-ssm-nq_results.csv")

# %%
results.head()
# Out:
#                                             question  id  \
# 0           who got the first nobel prize in physics   0
# 1     when is the next deadpool movie being released   1
# 2  which mode is used for short wave broadcast se...   2
# 3   the south west wind blows across nigeria between   3
# 4                 what does hp mean in war and order   4
#
#                            answers                 prediction  \
# 0       ['Wilhelm Conrad Röntgen']     Wilhelm Conrad Röntgen
# 1                ['May 18 , 2018']               May 18, 2018
# 2               ['Olivia', 'MFSK']                         CW
# 3               ['till September']  between April and October
# 4  ['hit points or health points']   Heuristically programmed
#
#                           overlap     em   f1  bert_score  meteor_score
# 0     ['total', 'answer_overlap']   True  1.0     1.00000      0.981481
# 1     ['total', 'answer_overlap']   True  1.0     0.75861      0.992188
# 2     ['total', 'answer_overlap']  False  0.0     0.29394      0.000000
# 3  ['total', 'no_answer_overlap']  False  0.0     0.25939      0.000000
# 4  ['total', 'no_answer_overlap']  False  0.0    -0.06745      0.000000

# %%
wrong_results = results[results['em'] == False]
tmp = []
for index, item in wrong_results.iterrows():
    # print(index)
    if 'no_answer_overlap' in ast.literal_eval(item['overlap']):
        tmp.append(dict(item))

# %%
no_overlap = pd.DataFrame(tmp)

# %%
no_overlap = no_overlap.sort_values('bert_score', ascending=False)

# %%
no_overlap[0:25]
# Out:
#                                                question    id  \
# 307    when does canada switch to daylight savings time   828
# 413              when did the first battle of ypres end  1143
# 440      what is the latest version of chrome for linux  1229
# 1030  what is the minimum dollar amount for federal ...  3067
# 165         what is the average height of a chinese man   442
# 976   when was the south asian association for regio...  2904
# 869          how many customers does edf have in the uk  2565
# 433   where does the red river start and end in loui...  1211
# 586   the complete collection of dna and genes is ca...  1655
# 912   where are alkali metals located on the periodi...  2698
# 391      where are the san juan mountains in new mexico  1053
# 466   who was the first president of the constituent...  1303
# 395   who played john connor in the original terminator  1082
# 1139           how much does a new gulfstream g650 cost  3345
# 1029  when did the vikings first sail and reach britain  3066
# 298      when did beryl markham fly across the atlantic   805
# 516   who was assassinated during a visit to sarajev...  1462
# 1046  who played shmuel in the boy in the striped py...  3099
# 618   what is a coherent set of values and beliefs a...  1729
# 231            total goals scored by ronaldo in la liga   634
# 653          when does jim propose to pam on the office  1837
# 546   when did the soviet union first gain control o...  1532
# 194      when is the new dumping ground coming out 2017   522
# 497   who pays medical bills in great britain where ...  1400
# 373               when does april fools day end at noon  1006
#
#                                                 answers  \
# 307                      ['the second Sunday of March']
# 413                                ['22 November 1914']
# 440                              ['67.0', '67.0. 3396']
# 1030                                        ['$75,000']
# 165                                       ['5 ft 6 in']
# 976                ['December 1985', '8 December 1985']
# 869    ['5.7 million', '5.7 million customer accounts']
# 433                             ['the Texas Panhandle']
# 586                            ['genome', 'chromosome']
# 912                     ['group 1', 'in the s - block']
# 391                         ['northwestern New Mexico']
# 466                             ['Dr. Rajendra Prasad']
# 395               ['Edward Furlong', 'Michael Edwards']
# 1139            ['US $ 66.61 million', '$66.5 million']
# 1029                    ['786 -- 802', '6 January 793']
# 298              ['4 September 1936', 'September 1936']
# 516             ['Archduke Franz Ferdinand of Austria']
# 1046                                   ['Jack Scanlon']
# 618   ['a political ideology', 'political ideology',...
# 231                                             ['309']
# 653                        ['In the Season 5 premiere']
# 546                                    ['14 June 1940']
# 194                                ['15 December 2017']
# 497                       ['general taxation', 'taxes']
# 373                                       ['April 1st']
#
#                         prediction  \
# 307     the second Sunday in March
# 413               30 November 1914
# 440                           63.0
# 1030                       $15,000
# 165                     5 ft 10 in
# 976                  8 August 1985
# 869                    1.4 million
# 433         in the Texas Panhandle
# 586                    chromosomes
# 912                        group 2
# 391            northern New Mexico
# 466       Dr. Rajendra Prasad, INC
# 395          Edward Walter Furlong
# 1139                $66.61 million
# 1029                    8 June 793
# 298                      July 1934
# 516       Archduke Franz Ferdinand
# 1046          Jack Charles Scanlon
# 618         a political philosophy
# 231                            311
# 653   in the season eight premiere
# 546              17 September 1939
# 194                13 October 2017
# 497        general taxation system
# 373                        April 1
#
#                                                 overlap     em        f1  \
# 307                      ['total', 'no_answer_overlap']  False  0.750000
# 413                      ['total', 'no_answer_overlap']  False  0.666667
# 440                      ['total', 'no_answer_overlap']  False  0.000000
# 1030                     ['total', 'no_answer_overlap']  False  0.000000
# 165                      ['total', 'no_answer_overlap']  False  0.750000
# 976                      ['total', 'no_answer_overlap']  False  0.666667
# 869                      ['total', 'no_answer_overlap']  False  0.500000
# 433                      ['total', 'no_answer_overlap']  False  0.800000
# 586                      ['total', 'no_answer_overlap']  False  0.000000
# 912                      ['total', 'no_answer_overlap']  False  0.500000
# 391                      ['total', 'no_answer_overlap']  False  0.666667
# 466                      ['total', 'no_answer_overlap']  False  0.857143
# 395                      ['total', 'no_answer_overlap']  False  0.800000
# 1139  ['total', 'no_answer_overlap', 'question_overl...  False  0.800000
# 1029                     ['total', 'no_answer_overlap']  False  0.333333
# 298                      ['total', 'no_answer_overlap']  False  0.000000
# 516   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.750000
# 1046                     ['total', 'no_answer_overlap']  False  0.800000
# 618                      ['total', 'no_answer_overlap']  False  0.500000
# 231   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.000000
# 653                      ['total', 'no_answer_overlap']  False  0.750000
# 546   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.000000
# 194   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.333333
# 497                      ['total', 'no_answer_overlap']  False  0.800000
# 373                      ['total', 'no_answer_overlap']  False  0.500000
#
#       bert_score  meteor_score
# 307      0.95117      0.750000
# 413      0.94158      0.625000
# 440      0.91343      0.000000
# 1030     0.90510      0.250000
# 165      0.90364      0.638889
# 976      0.88036      0.333333
# 869      0.87846      0.250000
# 433      0.87300      0.949821
# 586      0.86578      0.500000
# 912      0.86458      0.250000
# 391      0.86437      0.625000
# 466      0.85198      0.920139
# 395      0.84793      0.476190
# 1139     0.83101      0.754986
# 1029     0.82996      0.166667
# 298      0.82745      0.000000
# 516      0.82541      0.613426
# 1046     0.82250      0.476190
# 618      0.82127      0.625000
# 231      0.81769      0.000000
# 653      0.80807      0.750000
# 546      0.80312      0.000000
# 194      0.79609      0.166667
# 497      0.79533      0.892857
# 373      0.79509      0.250000

# %%
no_overlap.sort_values('meteor_score', ascending=False)[0:50]
# Out:
#                                                question    id  \
# 765      what is the name of the restaurant in seinfeld  2233
# 433   where does the red river start and end in loui...  1211
# 62    when did the the regulatory reform ( fire safe...   155
# 317         where is the tablet of the ten commandments   856
# 278    a good that can be used in place of another good   752
# 466   who was the first president of the constituent...  1303
# 213     which episode does gideon die in criminal minds   578
# 484          which is the ring finger for male in india  1360
# 1200  where does the electron transport chain get it...  3536
# 747   where does the electron transport chain pumps ...  2168
# 562                   what is the full form of ib board  1584
# 497   who pays medical bills in great britain where ...  1400
# 920         who was elected president in mexico in 2000  2721
# 161   who wrote the original little red riding hood ...   435
# 467   where was the u.s.s maine when it exploded in ...  1309
# 967              who votes in the baseball hall of fame  2870
# 745              who plays general hux in the last jedi  2165
# 1139           how much does a new gulfstream g650 cost  3345
# 653          when does jim propose to pam on the office  1837
# 307    when does canada switch to daylight savings time   828
# 800   one piece english dubbed episode 564 release date  2340
# 666                  what is the meaning of auv in cars  1887
# 839   where did immigrants enter the us on the west ...  2489
# 12                what type of car is a jeep considered    32
# 847   1 . what was the precursor to the present day ...  2513
# 1071  when did dragon ball super tournament of power...  3154
# 102              fast & furious 8 release date in india   262
# 165         what is the average height of a chinese man   442
# 742   royal society for the protection of birds numb...  2148
# 168          when did the first pair of yeezys come out   447
# 1053     what was guantanamo bay before it was a prison  3117
# 159   where does the ohio river and the mississippi ...   430
# 391      where are the san juan mountains in new mexico  1053
# 1214         first dynasty to issue gold coins in india  3575
# 413              when did the first battle of ypres end  1143
# 618   what is a coherent set of values and beliefs a...  1729
# 616   what is the strongest earthquake in the united...  1726
# 516   who was assassinated during a visit to sarajev...  1462
# 662   the first significant restriction on free immi...  1872
# 817   the art and science of making objects from cla...  2403
# 1153  who are the only 2 families that have had 3 ge...  3395
# 802   what happens when iron reacts with oxygen and ...  2352
# 586   the complete collection of dna and genes is ca...  1655
# 258        what was the religion in persia before islam   700
# 645           what started the war between us and japan  1814
# 103   the group that officially elects the president...   263
# 15     where does the story the great gatsby take place    39
# 322          where was 2017 beauty and the beast filmed   870
# 127            what genre is the magic tree house books   342
# 355   where do the secretory cells of endocrine glan...   954
#
#                                                 answers  \
# 765                         ["Monk 's", "Monk 's Café"]
# 433                             ['the Texas Panhandle']
# 62                                   ['1 October 2006']
# 317                             ['Ark of the Covenant']
# 278            ['substitute good', 'A substitute good']
# 466                             ['Dr. Rajendra Prasad']
# 213    ["`` Nelson 's Sparrow ''", "Nelson 's Sparrow"]
# 484        ['left ring finger', 'the left ring finger']
# 1200              ['donor molecule', 'electron donors']
# 747     ['across a membrane', 'mitochondrial membrane']
# 562   ['International Baccalaureate', 'The Internati...
# 497                       ['general taxation', 'taxes']
# 920                                     ['Vicente Fox']
# 161                                ['Charles Perrault']
# 467                                   ['Havana Harbor']
# 967   ['or the Veterans Committee', 'Veterans Commit...
# 745                                ['Domhnall Gleeson']
# 1139            ['US $ 66.61 million', '$66.5 million']
# 653                        ['In the Season 5 premiere']
# 307                      ['the second Sunday of March']
# 800                             ['September 16 , 2012']
# 666                         ['action utility vehicles']
# 839   ['Angel Island Immigration Station', 'San Fran...
# 12    ['off - road vehicles', 'sport utility vehicle...
# 847                             ['the ARPANET project']
# 1071                             ['February 19 , 2017']
# 102                                 ['April 12 , 2017']
# 165                                       ['5 ft 6 in']
# 742                             ['more than a million']
# 168                              ['February 14 , 2015']
# 1053                      ['Guantanamo Bay Naval Base']
# 159                                ['Cairo , Illinois']
# 391                         ['northwestern New Mexico']
# 1214                               ['The Gupta Empire']
# 413                                ['22 November 1914']
# 618   ['a political ideology', 'political ideology',...
# 616   ['1964 Alaska earthquake and tsunami', '1700 C...
# 516             ['Archduke Franz Ferdinand of Austria']
# 662   ['Naturalization Act of 1790', 'Chinese Exclus...
# 817                          ['Ceramic art', 'Ceramic']
# 1153  ['Farrow / Previn / Allens', 'the Coppolas', '...
# 802                                            ['Rust']
# 586                            ['genome', 'chromosome']
# 258         ['Zoroastrian', 'the Zoroastrian religion']
# 645                          ['attack on Pearl Harbor']
# 103   ['the U.S. Electoral College', 'U.S. Electoral...
# 15                              ['Long Island of 1922']
# 322                         ['Surrey , United Kingdom']
# 127                  ["Children 's historical fantasy"]
# 355   ['epithelial surface', 'directly into the bloo...
#
#                                     prediction  \
# 765                                Monk's Café
# 433                     in the Texas Panhandle
# 62                           on 1 October 2006
# 317                 on the Ark of the Covenant
# 278                           substitute goods
# 466                   Dr. Rajendra Prasad, INC
# 213                         "Nelson's Sparrow"
# 484                    ring finger of the left
# 1200                      from electron donors
# 747               inner mitochondrial membrane
# 562   International Baccalaureate Organization
# 497                    general taxation system
# 920                        Vicente Fox Quesada
# 161             French author Charles Perrault
# 467                        Havana Harbor, Cuba
# 967          members of the Veterans Committee
# 745            Domhnall Gleeson as General Hux
# 1139                            $66.61 million
# 653               in the season eight premiere
# 307                 the second Sunday in March
# 800                         September 16, 2018
# 666                            utility vehicle
# 839                              San Francisco
# 12                             utility vehicle
# 847                                the ARPANET
# 1071                          February 5, 2017
# 102                             April 14, 2017
# 165                                 5 ft 10 in
# 742                        more than 6 million
# 168                          February 13, 2015
# 1053              Naval Station Guantanamo Bay
# 159                       Pittsburgh, Illinois
# 391                        northern New Mexico
# 1214                         the Gupta dynasty
# 413                           30 November 1914
# 618                     a political philosophy
# 616                     1964 Alaska earthquake
# 516                   Archduke Franz Ferdinand
# 662                      Chinese Exclusion Act
# 817                                   ceramics
# 1153                                   Coppola
# 802                                    rusting
# 586                                chromosomes
# 258                             Zoroastrianism
# 645                               Pearl Harbor
# 103                          Electoral College
# 15                                 Long Island
# 322                            Surrey, England
# 127                           children's novel
# 355                             into the blood
#
#                                                 overlap     em        f1  \
# 765                      ['total', 'no_answer_overlap']  False  0.400000
# 433                      ['total', 'no_answer_overlap']  False  0.800000
# 62                       ['total', 'no_answer_overlap']  False  0.857143
# 317                      ['total', 'no_answer_overlap']  False  0.857143
# 278   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.500000
# 466                      ['total', 'no_answer_overlap']  False  0.857143
# 213   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.400000
# 484                      ['total', 'no_answer_overlap']  False  0.857143
# 1200                     ['total', 'no_answer_overlap']  False  0.800000
# 747                      ['total', 'no_answer_overlap']  False  0.800000
# 562                      ['total', 'no_answer_overlap']  False  0.800000
# 497                      ['total', 'no_answer_overlap']  False  0.800000
# 920   ['total', 'no_answer_overlap', 'question_overl...  False  0.800000
# 161                      ['total', 'no_answer_overlap']  False  0.666667
# 467                      ['total', 'no_answer_overlap']  False  0.800000
# 967                      ['total', 'no_answer_overlap']  False  0.666667
# 745                      ['total', 'no_answer_overlap']  False  0.571429
# 1139  ['total', 'no_answer_overlap', 'question_overl...  False  0.800000
# 653                      ['total', 'no_answer_overlap']  False  0.750000
# 307                      ['total', 'no_answer_overlap']  False  0.750000
# 800   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.666667
# 666   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.400000
# 839   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.800000
# 12                       ['total', 'no_answer_overlap']  False  0.400000
# 847                      ['total', 'no_answer_overlap']  False  0.666667
# 1071                     ['total', 'no_answer_overlap']  False  0.666667
# 102                      ['total', 'no_answer_overlap']  False  0.666667
# 165                      ['total', 'no_answer_overlap']  False  0.750000
# 742                      ['total', 'no_answer_overlap']  False  0.857143
# 168                      ['total', 'no_answer_overlap']  False  0.666667
# 1053                     ['total', 'no_answer_overlap']  False  0.750000
# 159                      ['total', 'no_answer_overlap']  False  0.500000
# 391                      ['total', 'no_answer_overlap']  False  0.666667
# 1214                     ['total', 'no_answer_overlap']  False  0.500000
# 413                      ['total', 'no_answer_overlap']  False  0.666667
# 618                      ['total', 'no_answer_overlap']  False  0.500000
# 616   ['total', 'no_answer_overlap', 'question_overl...  False  0.750000
# 516   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.750000
# 662                      ['total', 'no_answer_overlap']  False  0.750000
# 817                      ['total', 'no_answer_overlap']  False  0.000000
# 1153  ['total', 'no_answer_overlap', 'no_question_ov...  False  0.000000
# 802   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.000000
# 586                      ['total', 'no_answer_overlap']  False  0.000000
# 258   ['total', 'no_answer_overlap', 'no_question_ov...  False  0.000000
# 645                      ['total', 'no_answer_overlap']  False  0.666667
# 103                      ['total', 'no_answer_overlap']  False  0.800000
# 15                       ['total', 'no_answer_overlap']  False  0.666667
# 322                      ['total', 'no_answer_overlap']  False  0.400000
# 127                      ['total', 'no_answer_overlap']  False  0.000000
# 355                      ['total', 'no_answer_overlap']  False  0.400000
#
#       bert_score  meteor_score
# 765      0.74776      0.981481
# 433      0.87300      0.949821
# 62       0.74513      0.949821
# 317      0.70053      0.944940
# 278      0.63368      0.937500
# 466      0.85198      0.920139
# 213      0.54157      0.920139
# 484      0.59684      0.914634
# 1200     0.34920      0.892857
# 747      0.59817      0.892857
# 562      0.77375      0.892857
# 497      0.79533      0.892857
# 920      0.55825      0.892857
# 161      0.74315      0.852273
# 467      0.68916      0.852273
# 967      0.68172      0.815217
# 745      0.54206      0.815217
# 1139     0.83101      0.754986
# 653      0.80807      0.750000
# 307      0.95117      0.750000
# 800      0.50892      0.736111
# 666      0.57912      0.646552
# 839      0.72439      0.646552
# 12       0.69056      0.646552
# 847      0.73263      0.646552
# 1071     0.69130      0.638889
# 102      0.68709      0.638889
# 165      0.90364      0.638889
# 742      0.75107      0.638889
# 168      0.70211      0.638889
# 1053     0.55412      0.638889
# 159      0.44069      0.625000
# 391      0.86437      0.625000
# 1214     0.75220      0.625000
# 413      0.94158      0.625000
# 618      0.82127      0.625000
# 616      0.77546      0.613426
# 516      0.82541      0.613426
# 662      0.70799      0.613426
# 817      0.26669      0.500000
# 1153     0.41626      0.500000
# 802      0.01402      0.500000
# 586      0.86578      0.500000
# 258      0.74501      0.500000
# 645      0.45082      0.493421
# 103      0.58812      0.493421
# 15       0.57017      0.493421
# 322      0.67467      0.480769
# 127      0.37944      0.480769
# 355      0.53333      0.480769

# %%
import numpy as np

# %%
np.corrcoef(list(results['bert_score']), list(results['meteor_score']))
# Out:
# array([[1.        , 0.76750884],
#        [0.76750884, 1.        ]])

# %%
np.corrcoef(list(no_overlap['bert_score']), list(no_overlap['meteor_score']))
# Out:
# array([[1.        , 0.50711702],
#        [0.50711702, 1.        ]])

# %%
np.corrcoef(list(no_overlap['meteor']), list(no_overlap['exact_match']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/repos/stanford/project/odqa-experiments/odqa-experiments/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/repos/stanford/project/odqa-experiments/odqa-experiments/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/repos/stanford/project/odqa-experiments/odqa-experiments/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'meteor'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 np.corrcoef(list(no_overlap['meteor']), list(no_overlap['exact_match']))
#
# File ~/repos/stanford/project/odqa-experiments/odqa-experiments/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/repos/stanford/project/odqa-experiments/odqa-experiments/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'meteor'

# %%
from scipy.stats.stats import pearsonr
# Out:
# /var/folders/5c/rh_j56vx44n9xrrr4x_wcf0m0000gn/T/ipykernel_55294/2554227351.py:1: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
pearsonr(list(no_overlap['bert_score']), list(no_overlap['meteor_score'])) # proves correlation is significant!
# Out:
# (0.5071170150111484, 2.0575498323099597e-81)
